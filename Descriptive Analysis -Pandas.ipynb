# %%
import pandas as pd

# %%
df = pd.read_csv("mtcars.csv", index_col=0, skiprows=0)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# model
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
# mpg     32 non-null float64
# cyl     32 non-null int64
# disp    32 non-null float64
# hp      32 non-null int64
# drat    32 non-null float64
# wt      32 non-null float64
# qsec    32 non-null float64
# vs      32 non-null int64
# am      32 non-null int64
# gear    32 non-null int64
# carb    32 non-null int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
df.mpg
# Out:
# model
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# Name: mpg, dtype: float64

# %%
df['mpg']
# Out:
# model
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# Name: mpg, dtype: float64

# %%
df.loc['Valiant']
# Out:
# mpg      18.10
# cyl       6.00
# disp    225.00
# hp      105.00
# drat      2.76
# wt        3.46
# qsec     20.22
# vs        1.00
# am        0.00
# gear      3.00
# carb      1.00
# Name: Valiant, dtype: float64

# %%
df.columns
# Out:
# Index([u'mpg', u'cyl', u'disp', u'hp', u'drat', u'wt', u'qsec', u'vs', u'am',
#        u'gear', u'carb'],
#       dtype='object')

# %%
df.values
# Out:
# array([[ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.62 ,  16.46 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.875,  17.02 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 22.8  ,   4.   , 108.   ,  93.   ,   3.85 ,   2.32 ,  18.61 ,
#           1.   ,   1.   ,   4.   ,   1.   ],
#        [ 21.4  ,   6.   , 258.   , 110.   ,   3.08 ,   3.215,  19.44 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 18.7  ,   8.   , 360.   , 175.   ,   3.15 ,   3.44 ,  17.02 ,
#           0.   ,   0.   ,   3.   ,   2.   ],
#        [ 18.1  ,   6.   , 225.   , 105.   ,   2.76 ,   3.46 ,  20.22 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 14.3  ,   8.   , 360.   , 245.   ,   3.21 ,   3.57 ,  15.84 ,
#           0.   ,   0.   ,   3.   ,   4.   ],
#        [ 24.4  ,   4.   , 146.7  ,  62.   ,   3.69 ,   3.19 ,  20.   ,
#           1.   ,   0.   ,   4.   ,   2.   ],
# ...

# %%
df[1:3]
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# model
# Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710     22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
'mpg' in df.columns
# Out:
# True

# %%
#Question 1- What is the highest hp? 

df['hp'].max()
# Out:
# 335

# %%
#Question 2 - Which car has the highest hp? 
df['hp'].argmax()
# Out:
# /Users/Vanessa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   from ipykernel import kernelapp as app
# 'Maserati Bora'

# %%
#Question 3 - What is the highest mpg? 
df['mpg'].max()
# Out:
# 33.9

# %%
#Question 4 - Which car has the highest mpg? 
df['mpg'].argmax()
# Out:
# /Users/Vanessa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   from ipykernel import kernelapp as app
# 'Toyota Corolla'

# %%
#Question 5 - Create a sorted dataframe, based on mpg 
df.sort_values(by = ['mpg'])
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# ...

# %%
#Which car has the “best” combination of mpg and hp
#Question 6 - What logic did you use?
df['combo'] = df.hp / df.mpg
df.head()
df['combo'].argmax()
# or - df.assign(combo1 = df.hp / df.mpg) which temporarily display the column, good for previewing results before committing
# Out:
# /Users/Vanessa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
# 'Maserati Bora'

# %%
df.assign(combo1 = df.hp / df.mpg)
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb     combo
# model
# Mazda RX4             4  5.238095
# Mazda RX4 Wag         4  5.238095
# Datsun 710            1  4.078947
# Hornet 4 Drive        1  5.140187
# Hornet Sportabout     2  9.358289
